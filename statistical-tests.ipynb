# %% [markdown]
# # Statistical Tests Trials#
#
# This notebook will be used for testing of different statistical tests to be used for evaluating the Gaussianity of the noise in residuals for each model

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
from matplotlib.ticker import FormatStrFormatter

# %%
ks100 = []
ks1000 = []
ks10000 = []

D100 = []
D1000 = []
D10000 = []

# shapiro100 = []
# shapiro1000 = []
# shapiro10000 = []

# W100 = []
# W1000 = []
# W10000 = []


for i in range(500):

    # make a set of random numbers
    norm10000 = np.random.randn(10000)
    norm1000 = norm10000[0::10]
    norm100 = norm1000[0::10]

    # find KS test p-values
    ks100.append(stats.kstest(norm100, 'norm', alternative='greater')[1])
    ks1000.append(stats.kstest(norm1000, 'norm', alternative='greater')[1])
    ks10000.append(stats.kstest(norm10000, 'norm', alternative='greater')[1])
    
    # find KS test statistic-values
    D100.append(stats.kstest(norm100, 'norm', alternative='greater')[0])
    D1000.append(stats.kstest(norm1000, 'norm', alternative='greater')[0])
    D10000.append(stats.kstest(norm10000, 'norm', alternative='greater')[0])
    
#     # find Shapiro Wilk p-values
#     shapiro100.append(stats.shapiro(norm100)[1])
#     shapiro1000.append(stats.shapiro(norm1000)[1])
#     shapiro10000.append(stats.shapiro(norm10000)[1])
    
#     # find Shapiro Wilk statistic values
#     W100.append(stats.shapiro(norm100)[0])
#     W1000.append(stats.shapiro(norm1000)[0])
#     W10000.append(stats.shapiro(norm10000)[0])

# %%
# plot p-value distributions

fig, axes = plt.subplots(1, 3, sharex=True, sharey=True, figsize=(15,4))

ax1 = plt.subplot(1,3,1)
ax1.hist(ks100, bins=50, color='r')
ax1.set_title('100 samples')
plt.ylabel('Number of occurrences')

ax2 = plt.subplot(1,3,2)
ax2.hist(ks1000, bins=50, color='b')
ax2.set_title('1000 samples')
plt.xlabel('KS test p-value')

ax3 = plt.subplot(1,3,3)
ax3.hist(ks10000, bins=50, color='g')
ax3.set_title('10000 samples')

#plt.savefig('notes/kstest_pvalues.jpg')
# Out:
# Text(0.5, 1.0, '10000 samples')

# %%
# plot p-value distributions
fig, axes = plt.subplots(1, 3, sharex=True, sharey=True, figsize=(15,4))

ax1 = plt.subplot(1,3,1)
ax1.hist(np.array(D100)*np.sqrt(100), bins=50, color='r')
ax1.set_title('100 samples')
plt.ylabel('Number of occurrences')

ax2 = plt.subplot(1,3,2)
ax2.hist(np.array(D1000)*np.sqrt(1000), bins=50, color='b')
ax2.set_title('1000 samples')
plt.xlabel('KS test D-value')

ax3 = plt.subplot(1,3,3)
ax3.hist(np.array(D10000)*np.sqrt(10000), bins=50, color='g')
ax3.set_title('10000 samples')
#ax3.xaxis.set_major_formatter(FormatStrFormatter('%0.4f'))
#ax3.xaxis.set_major_locator(plt.MaxNLocator(5))

#plt.savefig('notes/kstest_Dvalues.jpg')
# Out:
# Text(0.5, 1.0, '10000 samples')

# %%
plt.figure()
plt.plot(np.array(D100)*np.sqrt(100),ks100, 'r.')
plt.plot(np.array(D1000)*np.sqrt(1000),ks1000,'b.')
plt.plot(np.array(D10000)*np.sqrt(10000),ks10000, 'g.')

print(np.min(np.array(D10000)*np.sqrt(10000)))
# Out:
# 0.3466247666950917

# %%
# plot p-value distributions

fig, axes = plt.subplots(1, 3, sharex=True, sharey=True, figsize=(15,4))

ax1 = plt.subplot(1,3,1)
ax1.hist(shapiro100, bins=50, color='r')
ax1.set_title('100 samples')
plt.ylabel('Number of occurrences')

ax2 = plt.subplot(1,3,2)
ax2.hist(shapiro1000, bins=50, color='b')
ax2.set_title('1000 samples')
plt.xlabel('Shapiro Wilk test p-value')

ax3 = plt.subplot(1,3,3)
ax3.hist(shapiro10000, bins=50, color='g')
ax3.set_title('10000 samples')

#plt.savefig('notes/shapirotest_pvalues.jpg')
# Out:
# Text(0.5, 1.0, '10000 samples')

# %%
# plot p-value distributions
fig, axes = plt.subplots(1, 3, sharex=True, sharey=True, figsize=(15,4))

ax1 = plt.subplot(1,3,1)
ax1.hist(W100, bins=50, color='r')
ax1.set_title('100 samples')
plt.ylabel('Number of occurrences')

ax2 = plt.subplot(1,3,2)
ax2.hist(W1000, bins=50, color='b')
ax2.set_title('1000 samples')
plt.xlabel('Shapiro Wilk test W-value')

ax3 = plt.subplot(1,3,3)
ax3.hist(W10000, bins=50, color='g')
ax3.set_title('10000 samples')
ax3.xaxis.set_major_formatter(FormatStrFormatter('%0.4f'))
ax3.xaxis.set_major_locator(plt.MaxNLocator(5))

#plt.savefig('notes/shapirotest_Wvalues.jpg')

# %%
plt.figure()
plt.plot(np.array(W100),shapiro100, 'r.')
plt.plot(np.array(W1000),shapiro1000,'b.')
plt.plot(np.array(W10000),shapiro10000, 'g.')

# %% [markdown]
# # Two Sided KS Test

# %%
LOC = 0
SCALE = 1

mean, var, skew, kurt = stats.kstwobign.stats(loc = LOC, scale = SCALE, moments='mvsk')
print(mean)
print(var)
# Out:
# 0.8687311606312806
# 0.06777320397409947

# %%
fig, ax = plt.subplots(1, 1)
n=1e2
x = np.linspace(stats.ksone.ppf(0.01, n), stats.ksone.ppf(0.99, n), 1000)
y = stats.ksone.pdf(x, n)
ax.plot(x, y, 'r.', lw=5, alpha=0.6, label='kstwobign pdf')
plt.hist(D100,normed=True)
# Out:
# /home/nitikayad96/.local/lib/python3.6/site-packages/ipykernel_launcher.py:6: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
# (array([ 4.18190637, 10.23466558, 11.00501675, 11.88541809,  7.26331106,
#          5.17235787,  2.31105352,  1.76080268,  0.77035117,  0.44020067]),
#  array([0.00056   , 0.01873353, 0.03690706, 0.05508059, 0.07325412,
#         0.09142765, 0.10960118, 0.12777471, 0.14594824, 0.16412177,
#         0.1822953 ]),
#  <a list of 10 Patch objects>)

# %%
CDF = []

for i in range(len(x)-1):
    CDF.append(1 - np.trapz(y[:i], x=x[:i]))

# %%
plt.figure()
plt.plot(np.array(D100)*np.sqrt(100),ks100, 'r.')
plt.plot(np.array(D1000)*np.sqrt(1000),ks1000,'b.')
plt.plot(np.array(D10000)*np.sqrt(10000),ks10000, 'g.')
plt.plot(x[1:]*np.sqrt(n),CDF)

# %%
print(D1000)
# Out:
# [0.02616139685037458, 0.024352842943695996, 0.023212146845102644, 0.02379591104872636, 0.026124708201787028, 0.030022410670865474, 0.04274478855053987, 0.017956747726093236, 0.0231141866801422, 0.027938575329898296, 0.03600655785452034, 0.027134052200444736, 0.02264625299168621, 0.023139394798070256, 0.025280619161221818, 0.024502328503376414, 0.027393046372674423, 0.016534789324259502, 0.021656318875926006, 0.017155286992001417, 0.018023796838267492, 0.022479264279277822, 0.028809017808451798, 0.018938506387003673, 0.03312071922855403, 0.02448558669619877, 0.023093981116204643, 0.032328344977862744, 0.04718836853819042, 0.02320309381954222, 0.031270967044055964, 0.033766899094171854, 0.03633201505853523, 0.03428768053999187, 0.027314625523056413, 0.03237523351042526, 0.01757235366380805, 0.036503113875068216, 0.037880059468251015, 0.02680700640602296, 0.022678482054383498, 0.02024660776989573, 0.03210601745485678, 0.026325399548510764, 0.03739165909592235, 0.04061895631359602, 0.03759580903908455, 0.029067232567654755, 0.051671234719149806, 0.022972676107673617, 0.02062351018044059, 0.02644127621699044, 0.025327064137994793, 0.0344656764205028, 0.016078278256462797, 0.021959466809326617, 0.04302828656087476, 0.027333626830347124, 0.04799793394223101, 0.03272821180357066, 0.022772603596392882, 0.026223818282536226, 0.02479162481292907, 0.01968751432743454, 0.02808746332345463, 0.028316626264961342, 0.01729858371682802, 0.016148430174652395, 0.0219621999572176, 0.04120179707232863, 0.030338155910548892, 0.05842227157129787, 0.014665410203870688, 0.046903998190974294, 0.025667249904607115, 0.02782820168682315, 0.027717659267518235, 0.017959187822697953, 0.026687240352410102, 0.03118105852848818, 0.018119465483149466, 0.028158046565165407, 0.04703742846816794, 0.024860626262959984, 0.028592452170627225, 0.01571254927003385, 0.03287805318259074, 0.027740956011181928, 0.03328379545579652, 0.01928803926003258, 0.05068240940699892, 0.01729716829373451, 0.013363195839241837, 0.015807639262076623, 0.026340314346247617, 0.027505186552941957, 0.027933912609730993, 0.0263191952196421, 0.01343306715888748, 0.03225114640594029, 0.019670647261378016, 0.030827170825637906, 0.02282343648178753, 0.018456197673726638, 0.031171183319022244, 0.01721374822421115, 0.03369824861443743, 0.018042146333176023, 0.038225575970653125, 0.02621677671002698, 0.02796661155286362, 0.02941454011662359, 0.039557334765115915, 0.025282686184663894, 0.020488129423449353, 0.021838954833581004, 0.02341298122162372, 0.033122920080328855, 0.025020707078708626, 0.03094455067850685, 0.03971990011149418, 0.042461529465729675, 0.039717729231708465, 0.015487233255753075, 0.0271253177466243, 0.019489367263309743, 0.022250078664685313, 0.02593694502888176, 0.018331232344419246, 0.03757937695311664, 0.027922779633199973, 0.026018540840811344, 0.02163271529287636, 0.03228209609724986, 0.01793636493149342, 0.017797736719163182, 0.024301785055983904, 0.03560244446158223, 0.017857484501821008, 0.035048105202989066, 0.019477690659522318, 0.06094090346006198, 0.02403343697135224, 0.02371820967223337, 0.02738278506553432, 0.02403149486720474, 0.020363683489826756, 0.026747850369818305, 0.034745118408166964, 0.02399570503370374, 0.027832716796049706, 0.04094893296331337, 0.019010578976671466, 0.017585917294623, 0.017039557041814812, 0.020341292021227586, 0.014599761457475435, 0.03479236143866091, 0.026795552506406306, 0.050770177820008755, 0.04568232468795547, 0.014713860755164593, 0.03502387268543139, 0.017636782004341822, 0.031051119664735727, 0.017674975742161758, 0.03582899494964492, 0.04177617494231414, 0.02015039840757271, 0.029430159954476065, 0.03176391519497901, 0.023752851611115622, 0.020363733840803755, 0.028612155921389715, 0.04270385629181728, 0.021539467078607433, 0.024674682594091668, 0.016085152695479388, 0.03670324533676678, 0.027470995544279286, 0.023423538431620816, 0.046609846954237755, 0.020902441462048116, 0.05519892071086813, 0.03268688322907132, 0.02322617665175 ...
